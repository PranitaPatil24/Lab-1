# %%
# Install required libraries (quiet mode for cleaner output)
# !pip install requests --quiet
import requests

def get_weather(city):
    api_key = "bef6cfc1f7354faf9e8f1683d23ee170"  # Replace with your real key from openweathermap.org
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)
    data = response.json()

    # Check if API call was successful
    if response.status_code == 200:
        print("City:", data["name"])
        print("Temperature:", data["main"]["temp"], "°C")
        print("Wind Speed:", data["wind"]["speed"], "m/s")
        print("Description:", data["weather"][0]["description"])
    else:
        print("Error:", data.get("message", "Unable to fetch weather data."))
        print("Check if your API key or city name is correct.")

# Example:
city_name = input("Enter city name: ")
get_weather(city_name)
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Enter city name:  Dhule
# City: Dhule
# Temperature: 21.61 °C
# Wind Speed: 2.6 m/s
# Description: clear sky

# %%
def get_weather(city):
    api_key = "bef6cfc1f7354faf9e8f1683d23ee170"  # Replace with your real key from openweathermap.org
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)
    data = response.json()

    # Check if API call was successful
    if response.status_code == 200:
        print("City:", data["name"])
        print("Temperature:", data["main"]["temp"], "°C")
        print("Wind Speed:", data["wind"]["speed"], "m/s")
        print("Description:", data["weather"][0]["description"])
    else:
        print("Error:", data.get("message", "Unable to fetch weather data."))
        print("Check if your API key or city name is correct.")

# Example:
city_name = input("Enter city name: ")
get_weather(city_name)
# Out:
# Enter city name:  nashik
# City: Nashik
# Temperature: 17.39 °C
# Wind Speed: 1.86 m/s
# Description: clear sky
